# %% [markdown]
# <p align="center">
# Universidade Federal de Alagoas</br>
#
# Instituto de Computação</br>
#
# </p>
#
# #Trabalho Prático AB2
#
# Disciplina: Sistemas Distribuídos
#
# Semestre letivo: 2017.1
#
# Professor: André Lage Freitas
#
# ## Especificação
#
# **Importante**. Leia atentamente essa seção pois só serão aceitos trabalhos que obedecerem as a especificações a seguir.
#
# Baseado(a) no exemplo a seguir de implementação do B-multicast em Julia, façam os exercícios descritos nesse documento.

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
# # R_multicast
# ### Definition: Reliability only guarantees that if at least one process has received the message: every other process (of the group) will receive as well. The sender can be a point of failure, but the processes can't; all processes are supposed to be correct.
# ### Implementation: It is implemented using a B_multicast underneath (which uses a reliable unicast underneath). Sender does a B_multicast and whenever a process receives the message: it will check wheter or not it didn't received it before. If it didn't: marks as received and does a B_multicast. If it did: nothing happens.
# ### Complexity: In the worst case: all processes succesfully receives the message from the sender, and then each process sends the message to every one again. Summing n² messages being sent.
# ### Proof: Suppose there are two correct processes i and j, and that I received the message while j didn't. But since I did receive the message, it would have run the B_multicast and sent the message to j. So, by contradiction: we've proven R_multicast's reliability.

# %%
 @everywhere function B_async_deliver(group, from, message)
    global received
#     println(message)
#     flush(stdout)
#     sleep(0.01)
    
    if !(from in received)
        push!(received, from)
        if (from != myid())
            B_async_multicast(group, message, B_async_deliver)
        end
        sleep(0.01)
    end
end

@everywhere function B_async_multicast(group, message, B_deliver)
    my_id = myid()
    @sync for i in group
        @spawnat i B_async_deliver(my_id, message)
    end
end

function R_async_multicast(group, message)
    @everywhere group global received = Set()

    @sync for i in group
        @spawnat i B_sync_multicast(group, message, B_sync_deliver)
    end
end

# %%
syncTimes = []
for i in 1:iterations
    println("$i -----------------------------------")
    flush(stdout)
    push!(syncTimes, @elapsed R_sync_multicast(group, "Sync hi  -- $i"))
    if i == 1
        println(counter)
    end
end

# %%
asyncTimes = []
asyncTotalTime = for i in 1:iterations
    println("$i -----------------------------------")
    flush(stdout)
    push!(asyncTimes, @elapsed R_async_multicast(group, "Async hi -- $i"))
end

# %%
syncTimes, asyncTimes = Array{Float64}(syncTimes), Array{Float64}(asyncTimes)
sort!(syncTimes), sort!(asyncTimes)
deleteat!(syncTimes, UnitRange(length(syncTimes) - 10, length(syncTimes)))
deleteat!(asyncTimes, UnitRange(length(asyncTimes) - 10, length(asyncTimes)))
syncTotalTime, asyncTotalTime = sum(syncTimes), sum(asyncTimes)
syncMeanTime, asyncMeanTime = mean(syncTimes), mean(asyncTimes)
syncStdTime, asyncStdTime = std(syncTimes), std(asyncTimes)

println("Sync total time: $syncTotalTime || Async total time: $asyncTotalTime")
println("Sync mean time: $syncMeanTime || Async mean time: $asyncMeanTime")
println("Sync std time: $syncStdTime || Async std time: $asyncStdTime")
println("Sync: $syncTimes")
println("Async: $asyncTimes")

# plot(1:length(syncTimes),
#          [syncTimes, asyncTimes],
#          title="Sync x Async B_multicast",
#          label=["Sync", "Async"],
#          xlabel="Runs",
#          ylabel="Time (s)")
groupedbar(
           ["R_multicast"],
           [syncMeanTime asyncMeanTime],
           yerr = [syncStdTime asyncStdTime],
           label = ["Sync", "Async"],
           xlabel = "Runs",
           ylabel = "Time (seconds)",
           title = "Sync x Async R_multicast",
           framestyle = :box)

# %%
# function B_multicast(g,m,B_deliver)
#    for p in g
#        remotecall(p, B_deliver, m)
#    end
# end

# Adding 3 processes (workers)
#addprocs(3)

# My group is composed by all workers
# g = workers()

# Multicasting "oi!" message to group `g` by assuming `println` as B_deliver function.
# B_multicast(g,"oi!",println)

# %% [markdown]
# ### Preparations

# %%
using Distributed
using Plots
using StatsPlots

function mean(array)
    return(sum(array) / length(array))
end

function std(array)
    s, m = 0, mean(array)
    for x in array
        s += (x - m)*(x - m)
    end
    return(sqrt(s / (length(array) - 1)))
end

z, iterations = 1.96, 50
rmprocs(workers())
addprocs(3)
group = workers()
# Out:
# 3-element Array{Int64,1}:
#  12
#  13
#  14

# %% [markdown]
# ### Exercício 1: Sincronismo (2,0 pontos)
#
# Adicione 10 processos com o comando `addprocs` abaixo.

# %% [markdown]
# Modifique a implementação do B-multicast para utilizar communicação síncrona.

# %%
@everywhere function B_deliver(message)
    println(message)
    sleep(0.01)
end

function B_sync_multicast(group, message, B_deliver)
    for i in group
        @sync @spawnat i B_deliver(message)
    end
end

function B_async_multicast(group, message, B_deliver)
    @sync for i in group
        @spawnat i B_deliver(message)
    end
end
# Out:
# B_async_multicast (generic function with 1 method)

# %% [markdown]
# Execute as duas versões do B-multicast (síncrona e assíncrona) e compare as saídas.

# %%
B_sync_multicast(group, "B_sync_multicast: Hello ^~^", B_deliver)
B_async_multicast(group, "B_async_multicast: Hello ^~^", B_deliver)
# Out:
#       From worker 2:	B_sync_multicast: Hello ^~^
#       From worker 3:	B_sync_multicast: Hello ^~^
#       From worker 4:	B_sync_multicast: Hello ^~^
#       From worker 5:	B_sync_multicast: Hello ^~^
#       From worker 6:	B_sync_multicast: Hello ^~^
#       From worker 7:	B_sync_multicast: Hello ^~^
#       From worker 8:	B_sync_multicast: Hello ^~^
#       From worker 9:	B_sync_multicast: Hello ^~^
#       From worker 10:	B_sync_multicast: Hello ^~^
#       From worker 11:	B_sync_multicast: Hello ^~^
#       From worker 2:	B_async_multicast: Hello ^~^
#       From worker 6:	B_async_multicast: Hello ^~^
#       From worker 9:	B_async_multicast: Hello ^~^
#       From worker 3:	B_async_multicast: Hello ^~^
#       From worker 4:	B_async_multicast: Hello ^~^
#       From worker 5:	B_async_multicast: Hello ^~^
#       From worker 7:	B_async_multicast: Hello ^~^
#       From worker 8:	B_async_multicast: Hello ^~^
#       From worker 10:	B_async_multicast: Hello ^~^
#       From worker 11:	B_async_multicast: Hello ^~^

# %% [markdown]
# A ordem das mensagens das saídas foram as mesmas para ambas versões do B-multicast? Por quê?
#
# **Resposta**: _Pois a versão assíncrona permite que o B_deliver de cada indivíduo do grupo seja executado em paralelo, e assim: não tem garantias de que a ordem que cada um vai terminar (e imprimir na tela) é a mesma sempre_
#
#
# ### Exercício 2: Análise de desempenho do B-multicast (2,0 pontos)
#
# Meça o tempo de execução duas versões do B-multicast (síncrona e assíncrona). Dica: utilize a macro `@time`.
# * Execute 50 vezes essa medição e construa um gráfico em forma de barras:
# 	* cada barra representando cada versão do B-multicast;
# 	* calcule e coloque no gráfico o [intervalo de confiança](https://en.wikipedia.org/wiki/Confidence_interval) com nível de 95%.

# %%
syncTimes = []
for i in 1:iterations
    println("$i ------------------------------------------")
    push!(syncTimes, @elapsed B_sync_multicast(group, "Sync  hi -- $i iteration", B_deliver))
end

asyncTimes = []
for i in 1:iterations
    println("$i ------------------------------------------")
    push!(asyncTimes, @elapsed B_async_multicast(group, "Async hi -- $i iteration", B_deliver))
end

syncTimes, asyncTimes = Array{Float64}(syncTimes), Array{Float64}(asyncTimes)
sort!(syncTimes), sort!(asyncTimes)
deleteat!(syncTimes, UnitRange(length(syncTimes) - 10, length(syncTimes)))
deleteat!(asyncTimes, UnitRange(length(asyncTimes) - 10, length(asyncTimes)))
syncTotalTime, asyncTotalTime = sum(syncTimes), sum(asyncTimes)
syncMeanTime, asyncMeanTime = mean(syncTimes), mean(asyncTimes)
syncStdTime, asyncStdTime = std(syncTimes), std(asyncTimes)
syncConfTime, asyncConfTime = z*syncStdTime/sqrt(length(syncTimes)), z*asyncStdTime/sqrt(length(asyncTimes))

println("Sync total time: $syncTotalTime || Async total time: $asyncTotalTime")
println("Sync mean time: $syncMeanTime || Async mean time: $asyncMeanTime")
println("Sync std time: $syncStdTime || Async std time: $asyncStdTime")
println("Sync: $syncTimes")
println("Async: $asyncTimes")
# Out:
# 1 ------------------------------------------
#       From worker 2:	Sync  hi -- 1 iteration
#       From worker 3:	Sync  hi -- 1 iteration
#       From worker 4:	Sync  hi -- 1 iteration
#       From worker 5:	Sync  hi -- 1 iteration
#       From worker 6:	Sync  hi -- 1 iteration
#       From worker 7:	Sync  hi -- 1 iteration
#       From worker 8:	Sync  hi -- 1 iteration
#       From worker 9:	Sync  hi -- 1 iteration
#       From worker 10:	Sync  hi -- 1 iteration
#       From worker 11:	Sync  hi -- 1 iteration
# 2 ------------------------------------------
#       From worker 2:	Sync  hi -- 2 iteration
#       From worker 3:	Sync  hi -- 2 iteration
#       From worker 4:	Sync  hi -- 2 iteration
#       From worker 5:	Sync  hi -- 2 iteration
#       From worker 6:	Sync  hi -- 2 iteration
#       From worker 7:	Sync  hi -- 2 iteration
#       From worker 8:	Sync  hi -- 2 iteration
#       From worker 9:	Sync  hi -- 2 iteration
#       From worker 10:	Sync  hi -- 2 iteration
#       From worker 11:	Sync  hi -- 2 iteration
# 3 ------------------------------------------
#       From worker 2:	Sync  hi -- 3 iteration
#       From worker 3:	Sync  hi -- 3 iteration
#       From worker 4:	Sync  hi -- 3 iteration
#       From worker 5:	Sync  hi -- 3 iteration
#       From worker 6:	Sync  hi -- 3 iteration
#       From worker 7:	Sync  hi -- 3 iteration
#       From worker 8:	Sync  hi -- 3 iteration
#       From worker 9:	Sync  hi -- 3 iteration
#       From worker 10:	Sync  hi -- 3 iteration
#       From worker 11:	Sync  hi -- 3 iteration
# 4 ------------------------------------------
#       From worker 2:	Sync  hi -- 4 iteration
#       From worker 3:	Sync  hi -- 4 iteration
#       From worker 4:	Sync  hi -- 4 iteration
#       From worker 5:	Sync  hi -- 4 iteration
#       From worker 6:	Sync  hi -- 4 iteration
#       From worker 7:	Sync  hi -- 4 iteration
#       From worker 8:	Sync  hi -- 4 iteration
#       From worker 9:	Sync  hi -- 4 iteration
#       From worker 10:	Sync  hi -- 4 iteration
#       From worker 11:	Sync  hi -- 4 iteration
# 5 ------------------------------------------
#       From worker 2:	Sync  hi -- 5 iteration
#       From worker 3:	Sync  hi -- 5 iteration
#       From worker 4:	Sync  hi -- 5 iteration
#       From worker 5:	Sync  hi -- 5 iteration
#       From worker 6:	Sync  hi -- 5 iteration
#       From worker 7:	Sync  hi -- 5 iteration
#       From worker 8:	Sync  hi -- 5 iteration
#       From worker 9:	Sync  hi -- 5 iteration
#       From worker 10:	Sync  hi -- 5 iteration
#       From worker 11:	Sync  hi -- 5 iteration
# 6 ------------------------------------------
#       From worker 2:	Sync  hi -- 6 iteration
#       From worker 3:	Sync  hi -- 6 iteration
#       From worker 4:	Sync  hi -- 6 iteration
#       From worker 5:	Sync  hi -- 6 iteration
#       From worker 6:	Sync  hi -- 6 iteration
#       From worker 7:	Sync  hi -- 6 iteration
#       From worker 8:	Sync  hi -- 6 iteration
#       From worker 9:	Sync  hi -- 6 iteration
#       From worker 10:	Sync  hi -- 6 iteration
#       From worker 11:	Sync  hi -- 6 iteration
# 7 ------------------------------------------
#       From worker 2:	Sync  hi -- 7 iteration
#       From worker 3:	Sync  hi -- 7 iteration
#       From worker 4:	Sync  hi -- 7 iteration
#       From worker 5:	Sync  hi -- 7 iteration
#       From worker 6:	Sync  hi -- 7 iteration
#       From worker 7:	Sync  hi -- 7 iteration
#       From worker 8:	Sync  hi -- 7 iteration
#       From worker 9:	Sync  hi -- 7 iteration
#       From worker 10:	Sync  hi -- 7 iteration
#       From worker 11:	Sync  hi -- 7 iteration
# 8 ------------------------------------------
#       From worker 2:	Sync  hi -- 8 iteration
#       From worker 3:	Sync  hi -- 8 iteration
#       From worker 4:	Sync  hi -- 8 iteration
#       From worker 5:	Sync  hi -- 8 iteration
#       From worker 6:	Sync  hi -- 8 iteration
#       From worker 7:	Sync  hi -- 8 iteration
#       From worker 8:	Sync  hi -- 8 iteration
#       From worker 9:	Sync  hi -- 8 iteration
#       From worker 10:	Sync  hi -- 8 iteration
#       From worker 11:	Sync  hi -- 8 iteration
# 9 ------------------------------------------
#       From worker 2:	Sync  hi -- 9 iteration
#       From worker 3:	Sync  hi -- 9 iteration
#       From worker 4:	Sync  hi -- 9 iteration
#       From worker 5:	Sync  hi -- 9 iteration
#       From worker 6:	Sync  hi -- 9 iteration
#       From worker 7:	Sync  hi -- 9 iteration
#       From worker 8:	Sync  hi -- 9 iteration
#       From worker 9:	Sync  hi -- 9 iteration
#       From worker 10:	Sync  hi -- 9 iteration
#       From worker 11:	Sync  hi -- 9 iteration
# 10 ------------------------------------------
#       From worker 2:	Sync  hi -- 10 iteration
#       From worker 3:	Sync  hi -- 10 iteration
#       From worker 4:	Sync  hi -- 10 iteration
#       From worker 5:	Sync  hi -- 10 iteration
#       From worker 6:	Sync  hi -- 10 iteration
#       From worker 7:	Sync  hi -- 10 iteration
#       From worker 8:	Sync  hi -- 10 iteration
#       From worker 9:	Sync  hi -- 10 iteration
#       From worker 10:	Sync  hi -- 10 iteration
#       From worker 11:	Sync  hi -- 10 iteration
# 11 ------------------------------------------
#       From worker 2:	Sync  hi -- 11 iteration
#       From worker 3:	Sync  hi -- 11 iteration
#       From worker 4:	Sync  hi -- 11 iteration
#       From worker 5:	Sync  hi -- 11 iteration
#       From worker 6:	Sync  hi -- 11 iteration
#       From worker 7:	Sync  hi -- 11 iteration
#       From worker 8:	Sync  hi -- 11 iteration
#       From worker 9:	Sync  hi -- 11 iteration
#       From worker 10:	Sync  hi -- 11 iteration
#       From worker 11:	Sync  hi -- 11 iteration
# 12 ------------------------------------------
#       From worker 2:	Sync  hi -- 12 iteration
#       From worker 3:	Sync  hi -- 12 iteration
#       From worker 4:	Sync  hi -- 12 iteration
#       From worker 5:	Sync  hi -- 12 iteration
#       From worker 6:	Sync  hi -- 12 iteration
#       From worker 7:	Sync  hi -- 12 iteration
#       From worker 8:	Sync  hi -- 12 iteration
#       From worker 9:	Sync  hi -- 12 iteration
#       From worker 10:	Sync  hi -- 12 iteration
#       From worker 11:	Sync  hi -- 12 iteration
# 13 ------------------------------------------
#       From worker 2:	Sync  hi -- 13 iteration
#       From worker 3:	Sync  hi -- 13 iteration
#       From worker 4:	Sync  hi -- 13 iteration
#       From worker 5:	Sync  hi -- 13 iteration
#       From worker 6:	Sync  hi -- 13 iteration
#       From worker 7:	Sync  hi -- 13 iteration
#       From worker 8:	Sync  hi -- 13 iteration
#       From worker 9:	Sync  hi -- 13 iteration
#       From worker 10:	Sync  hi -- 13 iteration
#       From worker 11:	Sync  hi -- 13 iteration
# 14 ------------------------------------------
#       From worker 2:	Sync  hi -- 14 iteration
#       From worker 3:	Sync  hi -- 14 iteration
#       From worker 4:	Sync  hi -- 14 iteration
#       From worker 5:	Sync  hi -- 14 iteration
#       From worker 6:	Sync  hi -- 14 iteration
#       From worker 7:	Sync  hi -- 14 iteration
#       From worker 8:	Sync  hi -- 14 iteration
#       From worker 9:	Sync  hi -- 14 iteration
#       From worker 10:	Sync  hi -- 14 iteration
#       From worker 11:	Sync  hi -- 14 iteration
# 15 ------------------------------------------
#       From worker 2:	Sync  hi -- 15 iteration
#       From worker 3:	Sync  hi -- 15 iteration
#       From worker 4:	Sync  hi -- 15 iteration
#       From worker 5:	Sync  hi -- 15 iteration
#       From worker 6:	Sync  hi -- 15 iteration
#       From worker 7:	Sync  hi -- 15 iteration
#       From worker 8:	Sync  hi -- 15 iteration
#       From worker 9:	Sync  hi -- 15 iteration
#       From worker 10:	Sync  hi -- 15 iteration
#       From worker 11:	Sync  hi -- 15 iteration
# 16 ------------------------------------------
#       From worker 2:	Sync  hi -- 16 iteration
#       From worker 3:	Sync  hi -- 16 iteration
#       From worker 4:	Sync  hi -- 16 iteration
#       From worker 5:	Sync  hi -- 16 iteration
#       From worker 6:	Sync  hi -- 16 iteration
#       From worker 7:	Sync  hi -- 16 iteration
#       From worker 8:	Sync  hi -- 16 iteration
#       From worker 9:	Sync  hi -- 16 iteration
#       From worker 10:	Sync  hi -- 16 iteration
#       From worker 11:	Sync  hi -- 16 iteration
# 17 ------------------------------------------
#       From worker 2:	Sync  hi -- 17 iteration
#       From worker 3:	Sync  hi -- 17 iteration
#       From worker 4:	Sync  hi -- 17 iteration
#       From worker 5:	Sync  hi -- 17 iteration
#       From worker 6:	Sync  hi -- 17 iteration
#       From worker 7:	Sync  hi -- 17 iteration
#       From worker 8:	Sync  hi -- 17 iteration
#       From worker 9:	Sync  hi -- 17 iteration
#       From worker 10:	Sync  hi -- 17 iteration
#       From worker 11:	Sync  hi -- 17 iteration
# 18 ------------------------------------------
#       From worker 2:	Sync  hi -- 18 iteration
#       From worker 3:	Sync  hi -- 18 iteration
#       From worker 4:	Sync  hi -- 18 iteration
#       From worker 5:	Sync  hi -- 18 iteration
#       From worker 6:	Sync  hi -- 18 iteration
#       From worker 7:	Sync  hi -- 18 iteration
#       From worker 8:	Sync  hi -- 18 iteration
#       From worker 9:	Sync  hi -- 18 iteration
#       From worker 10:	Sync  hi -- 18 iteration
#       From worker 11:	Sync  hi -- 18 iteration
# 19 ------------------------------------------
#       From worker 2:	Sync  hi -- 19 iteration
#       From worker 3:	Sync  hi -- 19 iteration
#       From worker 4:	Sync  hi -- 19 iteration
#       From worker 5:	Sync  hi -- 19 iteration
#       From worker 6:	Sync  hi -- 19 iteration
#       From worker 7:	Sync  hi -- 19 iteration
#       From worker 8:	Sync  hi -- 19 iteration
#       From worker 9:	Sync  hi -- 19 iteration
#       From worker 10:	Sync  hi -- 19 iteration
#       From worker 11:	Sync  hi -- 19 iteration
# 20 ------------------------------------------
#       From worker 2:	Sync  hi -- 20 iteration
#       From worker 3:	Sync  hi -- 20 iteration
#       From worker 4:	Sync  hi -- 20 iteration
#       From worker 5:	Sync  hi -- 20 iteration
#       From worker 6:	Sync  hi -- 20 iteration
#       From worker 7:	Sync  hi -- 20 iteration
#       From worker 8:	Sync  hi -- 20 iteration
#       From worker 9:	Sync  hi -- 20 iteration
#       From worker 10:	Sync  hi -- 20 iteration
#       From worker 11:	Sync  hi -- 20 iteration
# 21 ------------------------------------------
#       From worker 2:	Sync  hi -- 21 iteration
#       From worker 3:	Sync  hi -- 21 iteration
#       From worker 4:	Sync  hi -- 21 iteration
#       From worker 5:	Sync  hi -- 21 iteration
#       From worker 6:	Sync  hi -- 21 iteration
#       From worker 7:	Sync  hi -- 21 iteration
#       From worker 8:	Sync  hi -- 21 iteration
#       From worker 9:	Sync  hi -- 21 iteration
#       From worker 10:	Sync  hi -- 21 iteration
#       From worker 11:	Sync  hi -- 21 iteration
# 22 ------------------------------------------
#       From worker 2:	Sync  hi -- 22 iteration
#       From worker 3:	Sync  hi -- 22 iteration
#       From worker 4:	Sync  hi -- 22 iteration
#       From worker 5:	Sync  hi -- 22 iteration
#       From worker 6:	Sync  hi -- 22 iteration
#       From worker 7:	Sync  hi -- 22 iteration
#       From worker 8:	Sync  hi -- 22 iteration
#       From worker 9:	Sync  hi -- 22 iteration
#       From worker 10:	Sync  hi -- 22 iteration
#       From worker 11:	Sync  hi -- 22 iteration
# 23 ------------------------------------------
#       From worker 2:	Sync  hi -- 23 iteration
#       From worker 3:	Sync  hi -- 23 iteration
#       From worker 4:	Sync  hi -- 23 iteration
#       From worker 5:	Sync  hi -- 23 iteration
#       From worker 6:	Sync  hi -- 23 iteration
#       From worker 7:	Sync  hi -- 23 iteration
#       From worker 8:	Sync  hi -- 23 iteration
#       From worker 9:	Sync  hi -- 23 iteration
#       From worker 10:	Sync  hi -- 23 iteration
#       From worker 11:	Sync  hi -- 23 iteration
# 24 ------------------------------------------
#       From worker 2:	Sync  hi -- 24 iteration
#       From worker 3:	Sync  hi -- 24 iteration
#       From worker 4:	Sync  hi -- 24 iteration
#       From worker 5:	Sync  hi -- 24 iteration
#       From worker 6:	Sync  hi -- 24 iteration
#       From worker 7:	Sync  hi -- 24 iteration
#       From worker 8:	Sync  hi -- 24 iteration
#       From worker 9:	Sync  hi -- 24 iteration
#       From worker 10:	Sync  hi -- 24 iteration
#       From worker 11:	Sync  hi -- 24 iteration
# 25 ------------------------------------------
#       From worker 2:	Sync  hi -- 25 iteration
#       From worker 3:	Sync  hi -- 25 iteration
#       From worker 4:	Sync  hi -- 25 iteration
#       From worker 5:	Sync  hi -- 25 iteration
#       From worker 6:	Sync  hi -- 25 iteration
#       From worker 7:	Sync  hi -- 25 iteration
#       From worker 8:	Sync  hi -- 25 iteration
#       From worker 9:	Sync  hi -- 25 iteration
#       From worker 10:	Sync  hi -- 25 iteration
#       From worker 11:	Sync  hi -- 25 iteration
# 26 ------------------------------------------
#       From worker 2:	Sync  hi -- 26 iteration
#       From worker 3:	Sync  hi -- 26 iteration
#       From worker 4:	Sync  hi -- 26 iteration
#       From worker 5:	Sync  hi -- 26 iteration
#       From worker 6:	Sync  hi -- 26 iteration
#       From worker 7:	Sync  hi -- 26 iteration
#       From worker 8:	Sync  hi -- 26 iteration
#       From worker 9:	Sync  hi -- 26 iteration
#       From worker 10:	Sync  hi -- 26 iteration
#       From worker 11:	Sync  hi -- 26 iteration
# 27 ------------------------------------------
#       From worker 2:	Sync  hi -- 27 iteration
#       From worker 3:	Sync  hi -- 27 iteration
#       From worker 4:	Sync  hi -- 27 iteration
#       From worker 5:	Sync  hi -- 27 iteration
#       From worker 6:	Sync  hi -- 27 iteration
#       From worker 7:	Sync  hi -- 27 iteration
#       From worker 8:	Sync  hi -- 27 iteration
#       From worker 9:	Sync  hi -- 27 iteration
#       From worker 10:	Sync  hi -- 27 iteration
#       From worker 11:	Sync  hi -- 27 iteration
# 28 ------------------------------------------
#       From worker 2:	Sync  hi -- 28 iteration
#       From worker 3:	Sync  hi -- 28 iteration
#       From worker 4:	Sync  hi -- 28 iteration
#       From worker 5:	Sync  hi -- 28 iteration
#       From worker 6:	Sync  hi -- 28 iteration
#       From worker 7:	Sync  hi -- 28 iteration
#       From worker 8:	Sync  hi -- 28 iteration
#       From worker 9:	Sync  hi -- 28 iteration
#       From worker 10:	Sync  hi -- 28 iteration
#       From worker 11:	Sync  hi -- 28 iteration
# 29 ------------------------------------------
#       From worker 2:	Sync  hi -- 29 iteration
#       From worker 3:	Sync  hi -- 29 iteration
#       From worker 4:	Sync  hi -- 29 iteration
#       From worker 5:	Sync  hi -- 29 iteration
#       From worker 6:	Sync  hi -- 29 iteration
#       From worker 7:	Sync  hi -- 29 iteration
#       From worker 8:	Sync  hi -- 29 iteration
#       From worker 9:	Sync  hi -- 29 iteration
#       From worker 10:	Sync  hi -- 29 iteration
#       From worker 11:	Sync  hi -- 29 iteration
# 30 ------------------------------------------
#       From worker 2:	Sync  hi -- 30 iteration
#       From worker 3:	Sync  hi -- 30 iteration
#       From worker 4:	Sync  hi -- 30 iteration
#       From worker 5:	Sync  hi -- 30 iteration
#       From worker 6:	Sync  hi -- 30 iteration
#       From worker 7:	Sync  hi -- 30 iteration
#       From worker 8:	Sync  hi -- 30 iteration
#       From worker 9:	Sync  hi -- 30 iteration
#       From worker 10:	Sync  hi -- 30 iteration
#       From worker 11:	Sync  hi -- 30 iteration
# 31 ------------------------------------------
#       From worker 2:	Sync  hi -- 31 iteration
#       From worker 3:	Sync  hi -- 31 iteration
#       From worker 4:	Sync  hi -- 31 iteration
#       From worker 5:	Sync  hi -- 31 iteration
#       From worker 6:	Sync  hi -- 31 iteration
#       From worker 7:	Sync  hi -- 31 iteration
#       From worker 8:	Sync  hi -- 31 iteration
#       From worker 9:	Sync  hi -- 31 iteration
#       From worker 10:	Sync  hi -- 31 iteration
#       From worker 11:	Sync  hi -- 31 iteration
# 32 ------------------------------------------
#       From worker 2:	Sync  hi -- 32 iteration
#       From worker 3:	Sync  hi -- 32 iteration
#       From worker 4:	Sync  hi -- 32 iteration
#       From worker 5:	Sync  hi -- 32 iteration
#       From worker 6:	Sync  hi -- 32 iteration
#       From worker 7:	Sync  hi -- 32 iteration
#       From worker 8:	Sync  hi -- 32 iteration
#       From worker 9:	Sync  hi -- 32 iteration
#       From worker 10:	Sync  hi -- 32 iteration
#       From worker 11:	Sync  hi -- 32 iteration
# 33 ------------------------------------------
#       From worker 2:	Sync  hi -- 33 iteration
#       From worker 3:	Sync  hi -- 33 iteration
#       From worker 4:	Sync  hi -- 33 iteration
#       From worker 5:	Sync  hi -- 33 iteration
#       From worker 6:	Sync  hi -- 33 iteration
#       From worker 7:	Sync  hi -- 33 iteration
#       From worker 8:	Sync  hi -- 33 iteration
#       From worker 9:	Sync  hi -- 33 iteration
#       From worker 10:	Sync  hi -- 33 iteration
#       From worker 11:	Sync  hi -- 33 iteration
# 34 ------------------------------------------
#       From worker 2:	Sync  hi -- 34 iteration
#       From worker 3:	Sync  hi -- 34 iteration
#       From worker 4:	Sync  hi -- 34 iteration
#       From worker 5:	Sync  hi -- 34 iteration
#       From worker 6:	Sync  hi -- 34 iteration
#       From worker 7:	Sync  hi -- 34 iteration
#       From worker 8:	Sync  hi -- 34 iteration
#       From worker 9:	Sync  hi -- 34 iteration
#       From worker 10:	Sync  hi -- 34 iteration
#       From worker 11:	Sync  hi -- 34 iteration
# 35 ------------------------------------------
#       From worker 2:	Sync  hi -- 35 iteration
#       From worker 3:	Sync  hi -- 35 iteration
#       From worker 4:	Sync  hi -- 35 iteration
#       From worker 5:	Sync  hi -- 35 iteration
#       From worker 6:	Sync  hi -- 35 iteration
#       From worker 7:	Sync  hi -- 35 iteration
#       From worker 8:	Sync  hi -- 35 iteration
#       From worker 9:	Sync  hi -- 35 iteration
#       From worker 10:	Sync  hi -- 35 iteration
#       From worker 11:	Sync  hi -- 35 iteration
# 36 ------------------------------------------
#       From worker 2:	Sync  hi -- 36 iteration
#       From worker 3:	Sync  hi -- 36 iteration
#       From worker 4:	Sync  hi -- 36 iteration
#       From worker 5:	Sync  hi -- 36 iteration
#       From worker 6:	Sync  hi -- 36 iteration
#       From worker 7:	Sync  hi -- 36 iteration
#       From worker 8:	Sync  hi -- 36 iteration
#       From worker 9:	Sync  hi -- 36 iteration
#       From worker 10:	Sync  hi -- 36 iteration
#       From worker 11:	Sync  hi -- 36 iteration
# 37 ------------------------------------------
#       From worker 2:	Sync  hi -- 37 iteration
#       From worker 3:	Sync  hi -- 37 iteration
#       From worker 4:	Sync  hi -- 37 iteration
#       From worker 5:	Sync  hi -- 37 iteration
#       From worker 6:	Sync  hi -- 37 iteration
#       From worker 7:	Sync  hi -- 37 iteration
#       From worker 8:	Sync  hi -- 37 iteration
#       From worker 9:	Sync  hi -- 37 iteration
#       From worker 10:	Sync  hi -- 37 iteration
#       From worker 11:	Sync  hi -- 37 iteration
# 38 ------------------------------------------
#       From worker 2:	Sync  hi -- 38 iteration
#       From worker 3:	Sync  hi -- 38 iteration
#       From worker 4:	Sync  hi -- 38 iteration
#       From worker 5:	Sync  hi -- 38 iteration
#       From worker 6:	Sync  hi -- 38 iteration
#       From worker 7:	Sync  hi -- 38 iteration
#       From worker 8:	Sync  hi -- 38 iteration
#       From worker 9:	Sync  hi -- 38 iteration
#       From worker 10:	Sync  hi -- 38 iteration
#       From worker 11:	Sync  hi -- 38 iteration
# 39 ------------------------------------------
#       From worker 2:	Sync  hi -- 39 iteration
#       From worker 3:	Sync  hi -- 39 iteration
#       From worker 4:	Sync  hi -- 39 iteration
#       From worker 5:	Sync  hi -- 39 iteration
#       From worker 6:	Sync  hi -- 39 iteration
#       From worker 7:	Sync  hi -- 39 iteration
#       From worker 8:	Sync  hi -- 39 iteration
#       From worker 9:	Sync  hi -- 39 iteration
#       From worker 10:	Sync  hi -- 39 iteration
#       From worker 11:	Sync  hi -- 39 iteration
# 40 ------------------------------------------
#       From worker 2:	Sync  hi -- 40 iteration
#       From worker 3:	Sync  hi -- 40 iteration
#       From worker 4:	Sync  hi -- 40 iteration
#       From worker 5:	Sync  hi -- 40 iteration
#       From worker 6:	Sync  hi -- 40 iteration
#       From worker 7:	Sync  hi -- 40 iteration
#       From worker 8:	Sync  hi -- 40 iteration
#       From worker 9:	Sync  hi -- 40 iteration
#       From worker 10:	Sync  hi -- 40 iteration
#       From worker 11:	Sync  hi -- 40 iteration
# 41 ------------------------------------------
#       From worker 2:	Sync  hi -- 41 iteration
#       From worker 3:	Sync  hi -- 41 iteration
#       From worker 4:	Sync  hi -- 41 iteration
#       From worker 5:	Sync  hi -- 41 iteration
#       From worker 6:	Sync  hi -- 41 iteration
#       From worker 7:	Sync  hi -- 41 iteration
#       From worker 8:	Sync  hi -- 41 iteration
#       From worker 9:	Sync  hi -- 41 iteration
#       From worker 10:	Sync  hi -- 41 iteration
#       From worker 11:	Sync  hi -- 41 iteration
# 42 ------------------------------------------
#       From worker 2:	Sync  hi -- 42 iteration
#       From worker 3:	Sync  hi -- 42 iteration
#       From worker 4:	Sync  hi -- 42 iteration
#       From worker 5:	Sync  hi -- 42 iteration
#       From worker 6:	Sync  hi -- 42 iteration
#       From worker 7:	Sync  hi -- 42 iteration
#       From worker 8:	Sync  hi -- 42 iteration
#       From worker 9:	Sync  hi -- 42 iteration
#       From worker 10:	Sync  hi -- 42 iteration
#       From worker 11:	Sync  hi -- 42 iteration
# 43 ------------------------------------------
#       From worker 2:	Sync  hi -- 43 iteration
#       From worker 3:	Sync  hi -- 43 iteration
#       From worker 4:	Sync  hi -- 43 iteration
#       From worker 5:	Sync  hi -- 43 iteration
#       From worker 6:	Sync  hi -- 43 iteration
#       From worker 7:	Sync  hi -- 43 iteration
#       From worker 8:	Sync  hi -- 43 iteration
#       From worker 9:	Sync  hi -- 43 iteration
#       From worker 10:	Sync  hi -- 43 iteration
#       From worker 11:	Sync  hi -- 43 iteration
# 44 ------------------------------------------
#       From worker 2:	Sync  hi -- 44 iteration
#       From worker 3:	Sync  hi -- 44 iteration
#       From worker 4:	Sync  hi -- 44 iteration
#       From worker 5:	Sync  hi -- 44 iteration
#       From worker 6:	Sync  hi -- 44 iteration
#       From worker 7:	Sync  hi -- 44 iteration
#       From worker 8:	Sync  hi -- 44 iteration
#       From worker 9:	Sync  hi -- 44 iteration
#       From worker 10:	Sync  hi -- 44 iteration
#       From worker 11:	Sync  hi -- 44 iteration
# 45 ------------------------------------------
#       From worker 2:	Sync  hi -- 45 iteration
#       From worker 3:	Sync  hi -- 45 iteration
#       From worker 4:	Sync  hi -- 45 iteration
#       From worker 5:	Sync  hi -- 45 iteration
#       From worker 6:	Sync  hi -- 45 iteration
#       From worker 7:	Sync  hi -- 45 iteration
#       From worker 8:	Sync  hi -- 45 iteration
#       From worker 9:	Sync  hi -- 45 iteration
#       From worker 10:	Sync  hi -- 45 iteration
#       From worker 11:	Sync  hi -- 45 iteration
# 46 ------------------------------------------
#       From worker 2:	Sync  hi -- 46 iteration
#       From worker 3:	Sync  hi -- 46 iteration
#       From worker 4:	Sync  hi -- 46 iteration
#       From worker 5:	Sync  hi -- 46 iteration
#       From worker 6:	Sync  hi -- 46 iteration
#       From worker 7:	Sync  hi -- 46 iteration
#       From worker 8:	Sync  hi -- 46 iteration
#       From worker 9:	Sync  hi -- 46 iteration
#       From worker 10:	Sync  hi -- 46 iteration
#       From worker 11:	Sync  hi -- 46 iteration
# 47 ------------------------------------------
#       From worker 2:	Sync  hi -- 47 iteration
#       From worker 3:	Sync  hi -- 47 iteration
#       From worker 4:	Sync  hi -- 47 iteration
#       From worker 5:	Sync  hi -- 47 iteration
#       From worker 6:	Sync  hi -- 47 iteration
#       From worker 7:	Sync  hi -- 47 iteration
#       From worker 8:	Sync  hi -- 47 iteration
#       From worker 9:	Sync  hi -- 47 iteration
#       From worker 10:	Sync  hi -- 47 iteration
#       From worker 11:	Sync  hi -- 47 iteration
# 48 ------------------------------------------
#       From worker 2:	Sync  hi -- 48 iteration
#       From worker 3:	Sync  hi -- 48 iteration
#       From worker 4:	Sync  hi -- 48 iteration
#       From worker 5:	Sync  hi -- 48 iteration
#       From worker 6:	Sync  hi -- 48 iteration
#       From worker 7:	Sync  hi -- 48 iteration
#       From worker 8:	Sync  hi -- 48 iteration
#       From worker 9:	Sync  hi -- 48 iteration
#       From worker 10:	Sync  hi -- 48 iteration
#       From worker 11:	Sync  hi -- 48 iteration
# 49 ------------------------------------------
#       From worker 2:	Sync  hi -- 49 iteration
#       From worker 3:	Sync  hi -- 49 iteration
#       From worker 4:	Sync  hi -- 49 iteration
#       From worker 5:	Sync  hi -- 49 iteration
#       From worker 6:	Sync  hi -- 49 iteration
#       From worker 7:	Sync  hi -- 49 iteration
#       From worker 8:	Sync  hi -- 49 iteration
#       From worker 9:	Sync  hi -- 49 iteration
#       From worker 10:	Sync  hi -- 49 iteration
#       From worker 11:	Sync  hi -- 49 iteration
# 50 ------------------------------------------
#       From worker 2:	Sync  hi -- 50 iteration
#       From worker 3:	Sync  hi -- 50 iteration
#       From worker 4:	Sync  hi -- 50 iteration
#       From worker 5:	Sync  hi -- 50 iteration
#       From worker 6:	Sync  hi -- 50 iteration
#       From worker 7:	Sync  hi -- 50 iteration
#       From worker 8:	Sync  hi -- 50 iteration
#       From worker 9:	Sync  hi -- 50 iteration
#       From worker 10:	Sync  hi -- 50 iteration
#       From worker 11:	Sync  hi -- 50 iteration
# 1 ------------------------------------------
#       From worker 2:	Async hi -- 1 iteration
#       From worker 5:	Async hi -- 1 iteration
#       From worker 8:	Async hi -- 1 iteration
#       From worker 10:	Async hi -- 1 iteration
#       From worker 3:	Async hi -- 1 iteration
#       From worker 4:	Async hi -- 1 iteration
#       From worker 6:	Async hi -- 1 iteration
#       From worker 7:	Async hi -- 1 iteration
#       From worker 9:	Async hi -- 1 iteration
#       From worker 11:	Async hi -- 1 iteration
# 2 ------------------------------------------
#       From worker 2:	Async hi -- 2 iteration
#       From worker 3:	Async hi -- 2 iteration
#       From worker 10:	Async hi -- 2 iteration
#       From worker 5:	Async hi -- 2 iteration
#       From worker 4:	Async hi -- 2 iteration
#       From worker 6:	Async hi -- 2 iteration
#       From worker 7:	Async hi -- 2 iteration
#       From worker 8:	Async hi -- 2 iteration
#       From worker 9:	Async hi -- 2 iteration
#       From worker 11:	Async hi -- 2 iteration
# 3 ------------------------------------------
#       From worker 2:	Async hi -- 3 iteration
#       From worker 7:	Async hi -- 3 iteration
#       From worker 9:	Async hi -- 3 iteration
#       From worker 3:	Async hi -- 3 iteration
#       From worker 4:	Async hi -- 3 iteration
#       From worker 5:	Async hi -- 3 iteration
#       From worker 6:	Async hi -- 3 iteration
#       From worker 8:	Async hi -- 3 iteration
#       From worker 10:	Async hi -- 3 iteration
#       From worker 11:	Async hi -- 3 iteration
# 4 ------------------------------------------
#       From worker 2:	Async hi -- 4 iteration
#       From worker 3:	Async hi -- 4 iteration
#       From worker 10:	Async hi -- 4 iteration
#       From worker 4:	Async hi -- 4 iteration
#       From worker 5:	Async hi -- 4 iteration
#       From worker 6:	Async hi -- 4 iteration
#       From worker 7:	Async hi -- 4 iteration
#       From worker 8:	Async hi -- 4 iteration
#       From worker 9:	Async hi -- 4 iteration
#       From worker 11:	Async hi -- 4 iteration
# 5 ------------------------------------------
#       From worker 2:	Async hi -- 5 iteration
#       From worker 6:	Async hi -- 5 iteration
#       From worker 9:	Async hi -- 5 iteration
#       From worker 3:	Async hi -- 5 iteration
#       From worker 4:	Async hi -- 5 iteration
#       From worker 5:	Async hi -- 5 iteration
#       From worker 7:	Async hi -- 5 iteration
#       From worker 8:	Async hi -- 5 iteration
#       From worker 10:	Async hi -- 5 iteration
#       From worker 11:	Async hi -- 5 iteration
# 6 ------------------------------------------
#       From worker 2:	Async hi -- 6 iteration
#       From worker 6:	Async hi -- 6 iteration
#       From worker 9:	Async hi -- 6 iteration
#       From worker 3:	Async hi -- 6 iteration
#       From worker 4:	Async hi -- 6 iteration
#       From worker 5:	Async hi -- 6 iteration
#       From worker 7:	Async hi -- 6 iteration
#       From worker 8:	Async hi -- 6 iteration
#       From worker 10:	Async hi -- 6 iteration
#       From worker 11:	Async hi -- 6 iteration
# 7 ------------------------------------------
#       From worker 2:	Async hi -- 7 iteration
#       From worker 7:	Async hi -- 7 iteration
#       From worker 10:	Async hi -- 7 iteration
#       From worker 3:	Async hi -- 7 iteration
#       From worker 5:	Async hi -- 7 iteration
#       From worker 4:	Async hi -- 7 iteration
#       From worker 6:	Async hi -- 7 iteration
#       From worker 8:	Async hi -- 7 iteration
#       From worker 9:	Async hi -- 7 iteration
#       From worker 11:	Async hi -- 7 iteration
# 8 ------------------------------------------
#       From worker 2:	Async hi -- 8 iteration
#       From worker 6:	Async hi -- 8 iteration
#       From worker 9:	Async hi -- 8 iteration
#       From worker 3:	Async hi -- 8 iteration
#       From worker 4:	Async hi -- 8 iteration
#       From worker 5:	Async hi -- 8 iteration
#       From worker 7:	Async hi -- 8 iteration
#       From worker 8:	Async hi -- 8 iteration
#       From worker 10:	Async hi -- 8 iteration
#       From worker 11:	Async hi -- 8 iteration
# 9 ------------------------------------------
#       From worker 2:	Async hi -- 9 iteration
#       From worker 3:	Async hi -- 9 iteration
#       From worker 10:	Async hi -- 9 iteration
#       From worker 5:	Async hi -- 9 iteration
#       From worker 4:	Async hi -- 9 iteration
#       From worker 6:	Async hi -- 9 iteration
#       From worker 7:	Async hi -- 9 iteration
#       From worker 8:	Async hi -- 9 iteration
#       From worker 9:	Async hi -- 9 iteration
#       From worker 11:	Async hi -- 9 iteration
# 10 ------------------------------------------
#       From worker 2:	Async hi -- 10 iteration
#       From worker 7:	Async hi -- 10 iteration
#       From worker 10:	Async hi -- 10 iteration
#       From worker 3:	Async hi -- 10 iteration
#       From worker 4:	Async hi -- 10 iteration
#       From worker 5:	Async hi -- 10 iteration
#       From worker 6:	Async hi -- 10 iteration
#       From worker 8:	Async hi -- 10 iteration
#       From worker 9:	Async hi -- 10 iteration
#       From worker 11:	Async hi -- 10 iteration
# 11 ------------------------------------------
#       From worker 2:	Async hi -- 11 iteration
#       From worker 7:	Async hi -- 11 iteration
#       From worker 9:	Async hi -- 11 iteration
#       From worker 3:	Async hi -- 11 iteration
#       From worker 4:	Async hi -- 11 iteration
#       From worker 5:	Async hi -- 11 iteration
#       From worker 6:	Async hi -- 11 iteration
#       From worker 8:	Async hi -- 11 iteration
#       From worker 10:	Async hi -- 11 iteration
#       From worker 11:	Async hi -- 11 iteration
# 12 ------------------------------------------
#       From worker 2:	Async hi -- 12 iteration
#       From worker 7:	Async hi -- 12 iteration
#       From worker 3:	Async hi -- 12 iteration
#       From worker 4:	Async hi -- 12 iteration
#       From worker 5:	Async hi -- 12 iteration
#       From worker 6:	Async hi -- 12 iteration
#       From worker 8:	Async hi -- 12 iteration
#       From worker 9:	Async hi -- 12 iteration
#       From worker 10:	Async hi -- 12 iteration
#       From worker 11:	Async hi -- 12 iteration
# 13 ------------------------------------------
#       From worker 2:	Async hi -- 13 iteration
#       From worker 6:	Async hi -- 13 iteration
#       From worker 9:	Async hi -- 13 iteration
#       From worker 3:	Async hi -- 13 iteration
#       From worker 4:	Async hi -- 13 iteration
#       From worker 5:	Async hi -- 13 iteration
#       From worker 7:	Async hi -- 13 iteration
#       From worker 8:	Async hi -- 13 iteration
#       From worker 10:	Async hi -- 13 iteration
#       From worker 11:	Async hi -- 13 iteration
# 14 ------------------------------------------
#       From worker 3:	Async hi -- 14 iteration
#       From worker 7:	Async hi -- 14 iteration
#       From worker 10:	Async hi -- 14 iteration
#       From worker 2:	Async hi -- 14 iteration
#       From worker 4:	Async hi -- 14 iteration
#       From worker 5:	Async hi -- 14 iteration
#       From worker 6:	Async hi -- 14 iteration
#       From worker 8:	Async hi -- 14 iteration
#       From worker 9:	Async hi -- 14 iteration
#       From worker 11:	Async hi -- 14 iteration
# 15 ------------------------------------------
#       From worker 2:	Async hi -- 15 iteration
#       From worker 6:	Async hi -- 15 iteration
#       From worker 9:	Async hi -- 15 iteration
#       From worker 3:	Async hi -- 15 iteration
#       From worker 4:	Async hi -- 15 iteration
#       From worker 5:	Async hi -- 15 iteration
#       From worker 7:	Async hi -- 15 iteration
#       From worker 8:	Async hi -- 15 iteration
#       From worker 10:	Async hi -- 15 iteration
#       From worker 11:	Async hi -- 15 iteration
# 16 ------------------------------------------
#       From worker 2:	Async hi -- 16 iteration
#       From worker 6:	Async hi -- 16 iteration
#       From worker 9:	Async hi -- 16 iteration
#       From worker 3:	Async hi -- 16 iteration
#       From worker 4:	Async hi -- 16 iteration
#       From worker 5:	Async hi -- 16 iteration
#       From worker 7:	Async hi -- 16 iteration
#       From worker 8:	Async hi -- 16 iteration
#       From worker 10:	Async hi -- 16 iteration
#       From worker 11:	Async hi -- 16 iteration
# 17 ------------------------------------------
#       From worker 2:	Async hi -- 17 iteration
#       From worker 7:	Async hi -- 17 iteration
#       From worker 11:	Async hi -- 17 iteration
#       From worker 3:	Async hi -- 17 iteration
#       From worker 4:	Async hi -- 17 iteration
#       From worker 5:	Async hi -- 17 iteration
#       From worker 6:	Async hi -- 17 iteration
#       From worker 8:	Async hi -- 17 iteration
#       From worker 9:	Async hi -- 17 iteration
#       From worker 10:	Async hi -- 17 iteration
# 18 ------------------------------------------
#       From worker 2:	Async hi -- 18 iteration
#       From worker 6:	Async hi -- 18 iteration
#       From worker 9:	Async hi -- 18 iteration
#       From worker 3:	Async hi -- 18 iteration
#       From worker 4:	Async hi -- 18 iteration
#       From worker 5:	Async hi -- 18 iteration
#       From worker 7:	Async hi -- 18 iteration
#       From worker 8:	Async hi -- 18 iteration
#       From worker 10:	Async hi -- 18 iteration
#       From worker 11:	Async hi -- 18 iteration
# 19 ------------------------------------------
#       From worker 2:	Async hi -- 19 iteration
#       From worker 6:	Async hi -- 19 iteration
#       From worker 3:	Async hi -- 19 iteration
#       From worker 4:	Async hi -- 19 iteration
#       From worker 5:	Async hi -- 19 iteration
#       From worker 7:	Async hi -- 19 iteration
#       From worker 8:	Async hi -- 19 iteration
#       From worker 9:	Async hi -- 19 iteration
#       From worker 10:	Async hi -- 19 iteration
#       From worker 11:	Async hi -- 19 iteration
# 20 ------------------------------------------
#       From worker 2:	Async hi -- 20 iteration
#       From worker 7:	Async hi -- 20 iteration
#       From worker 9:	Async hi -- 20 iteration
#       From worker 3:	Async hi -- 20 iteration
#       From worker 4:	Async hi -- 20 iteration
#       From worker 5:	Async hi -- 20 iteration
#       From worker 6:	Async hi -- 20 iteration
#       From worker 8:	Async hi -- 20 iteration
#       From worker 10:	Async hi -- 20 iteration
#       From worker 11:	Async hi -- 20 iteration
# 21 ------------------------------------------
#       From worker 2:	Async hi -- 21 iteration
#       From worker 6:	Async hi -- 21 iteration
#       From worker 8:	Async hi -- 21 iteration
#       From worker 3:	Async hi -- 21 iteration
#       From worker 4:	Async hi -- 21 iteration
#       From worker 5:	Async hi -- 21 iteration
#       From worker 7:	Async hi -- 21 iteration
#       From worker 9:	Async hi -- 21 iteration
#       From worker 10:	Async hi -- 21 iteration
#       From worker 11:	Async hi -- 21 iteration
# 22 ------------------------------------------
#       From worker 2:	Async hi -- 22 iteration
#       From worker 6:	Async hi -- 22 iteration
#       From worker 10:	Async hi -- 22 iteration
#       From worker 3:	Async hi -- 22 iteration
#       From worker 4:	Async hi -- 22 iteration
#       From worker 5:	Async hi -- 22 iteration
#       From worker 7:	Async hi -- 22 iteration
#       From worker 8:	Async hi -- 22 iteration
#       From worker 9:	Async hi -- 22 iteration
#       From worker 11:	Async hi -- 22 iteration
# 23 ------------------------------------------
#       From worker 3:	Async hi -- 23 iteration
#       From worker 6:	Async hi -- 23 iteration
#       From worker 2:	Async hi -- 23 iteration
#       From worker 4:	Async hi -- 23 iteration
#       From worker 5:	Async hi -- 23 iteration
#       From worker 7:	Async hi -- 23 iteration
#       From worker 8:	Async hi -- 23 iteration
#       From worker 9:	Async hi -- 23 iteration
#       From worker 10:	Async hi -- 23 iteration
#       From worker 11:	Async hi -- 23 iteration
# 24 ------------------------------------------
#       From worker 2:	Async hi -- 24 iteration
#       From worker 7:	Async hi -- 24 iteration
#       From worker 10:	Async hi -- 24 iteration
#       From worker 3:	Async hi -- 24 iteration
#       From worker 4:	Async hi -- 24 iteration
#       From worker 5:	Async hi -- 24 iteration
#       From worker 6:	Async hi -- 24 iteration
#       From worker 8:	Async hi -- 24 iteration
#       From worker 9:	Async hi -- 24 iteration
#       From worker 11:	Async hi -- 24 iteration
# 25 ------------------------------------------
#       From worker 2:	Async hi -- 25 iteration
#       From worker 7:	Async hi -- 25 iteration
#       From worker 3:	Async hi -- 25 iteration
#       From worker 4:	Async hi -- 25 iteration
#       From worker 6:	Async hi -- 25 iteration
#       From worker 5:	Async hi -- 25 iteration
#       From worker 8:	Async hi -- 25 iteration
#       From worker 9:	Async hi -- 25 iteration
#       From worker 10:	Async hi -- 25 iteration
#       From worker 11:	Async hi -- 25 iteration
# 26 ------------------------------------------
#       From worker 2:	Async hi -- 26 iteration
#       From worker 6:	Async hi -- 26 iteration
#       From worker 9:	Async hi -- 26 iteration
#       From worker 3:	Async hi -- 26 iteration
#       From worker 4:	Async hi -- 26 iteration
#       From worker 5:	Async hi -- 26 iteration
#       From worker 7:	Async hi -- 26 iteration
#       From worker 8:	Async hi -- 26 iteration
#       From worker 10:	Async hi -- 26 iteration
#       From worker 11:	Async hi -- 26 iteration
# 27 ------------------------------------------
#       From worker 2:	Async hi -- 27 iteration
#       From worker 7:	Async hi -- 27 iteration
#       From worker 9:	Async hi -- 27 iteration
#       From worker 3:	Async hi -- 27 iteration
#       From worker 4:	Async hi -- 27 iteration
#       From worker 5:	Async hi -- 27 iteration
#       From worker 6:	Async hi -- 27 iteration
#       From worker 8:	Async hi -- 27 iteration
#       From worker 10:	Async hi -- 27 iteration
#       From worker 11:	Async hi -- 27 iteration
# 28 ------------------------------------------
#       From worker 2:	Async hi -- 28 iteration
#       From worker 7:	Async hi -- 28 iteration
#       From worker 9:	Async hi -- 28 iteration
#       From worker 3:	Async hi -- 28 iteration
#       From worker 4:	Async hi -- 28 iteration
#       From worker 5:	Async hi -- 28 iteration
#       From worker 6:	Async hi -- 28 iteration
#       From worker 8:	Async hi -- 28 iteration
#       From worker 10:	Async hi -- 28 iteration
#       From worker 11:	Async hi -- 28 iteration
# 29 ------------------------------------------
#       From worker 2:	Async hi -- 29 iteration
#       From worker 6:	Async hi -- 29 iteration
#       From worker 9:	Async hi -- 29 iteration
#       From worker 3:	Async hi -- 29 iteration
#       From worker 4:	Async hi -- 29 iteration
#       From worker 5:	Async hi -- 29 iteration
#       From worker 7:	Async hi -- 29 iteration
#       From worker 8:	Async hi -- 29 iteration
#       From worker 10:	Async hi -- 29 iteration
#       From worker 11:	Async hi -- 29 iteration
# 30 ------------------------------------------
#       From worker 2:	Async hi -- 30 iteration
#       From worker 6:	Async hi -- 30 iteration
#       From worker 8:	Async hi -- 30 iteration
#       From worker 10:	Async hi -- 30 iteration
#       From worker 3:	Async hi -- 30 iteration
#       From worker 4:	Async hi -- 30 iteration
#       From worker 5:	Async hi -- 30 iteration
#       From worker 7:	Async hi -- 30 iteration
#       From worker 9:	Async hi -- 30 iteration
#       From worker 11:	Async hi -- 30 iteration
# 31 ------------------------------------------
#       From worker 2:	Async hi -- 31 iteration
#       From worker 6:	Async hi -- 31 iteration
#       From worker 9:	Async hi -- 31 iteration
#       From worker 3:	Async hi -- 31 iteration
#       From worker 4:	Async hi -- 31 iteration
#       From worker 5:	Async hi -- 31 iteration
#       From worker 7:	Async hi -- 31 iteration
#       From worker 8:	Async hi -- 31 iteration
#       From worker 10:	Async hi -- 31 iteration
#       From worker 11:	Async hi -- 31 iteration
# 32 ------------------------------------------
#       From worker 2:	Async hi -- 32 iteration
#       From worker 6:	Async hi -- 32 iteration
#       From worker 3:	Async hi -- 32 iteration
#       From worker 11:	Async hi -- 32 iteration
#       From worker 4:	Async hi -- 32 iteration
#       From worker 5:	Async hi -- 32 iteration
#       From worker 7:	Async hi -- 32 iteration
#       From worker 8:	Async hi -- 32 iteration
#       From worker 9:	Async hi -- 32 iteration
#       From worker 10:	Async hi -- 32 iteration
# 33 ------------------------------------------
#       From worker 2:	Async hi -- 33 iteration
#       From worker 6:	Async hi -- 33 iteration
#       From worker 9:	Async hi -- 33 iteration
#       From worker 3:	Async hi -- 33 iteration
#       From worker 4:	Async hi -- 33 iteration
#       From worker 5:	Async hi -- 33 iteration
#       From worker 7:	Async hi -- 33 iteration
#       From worker 8:	Async hi -- 33 iteration
#       From worker 10:	Async hi -- 33 iteration
#       From worker 11:	Async hi -- 33 iteration
# 34 ------------------------------------------
#       From worker 2:	Async hi -- 34 iteration
#       From worker 6:	Async hi -- 34 iteration
#       From worker 8:	Async hi -- 34 iteration
#       From worker 11:	Async hi -- 34 iteration
#       From worker 3:	Async hi -- 34 iteration
#       From worker 4:	Async hi -- 34 iteration
#       From worker 5:	Async hi -- 34 iteration
#       From worker 7:	Async hi -- 34 iteration
#       From worker 9:	Async hi -- 34 iteration
#       From worker 10:	Async hi -- 34 iteration
# 35 ------------------------------------------
#       From worker 2:	Async hi -- 35 iteration
#       From worker 6:	Async hi -- 35 iteration
#       From worker 3:	Async hi -- 35 iteration
#       From worker 11:	Async hi -- 35 iteration
#       From worker 4:	Async hi -- 35 iteration
#       From worker 5:	Async hi -- 35 iteration
#       From worker 7:	Async hi -- 35 iteration
#       From worker 8:	Async hi -- 35 iteration
#       From worker 9:	Async hi -- 35 iteration
#       From worker 10:	Async hi -- 35 iteration
# 36 ------------------------------------------
#       From worker 2:	Async hi -- 36 iteration
#       From worker 6:	Async hi -- 36 iteration
#       From worker 9:	Async hi -- 36 iteration
#       From worker 3:	Async hi -- 36 iteration
#       From worker 4:	Async hi -- 36 iteration
#       From worker 5:	Async hi -- 36 iteration
#       From worker 7:	Async hi -- 36 iteration
#       From worker 8:	Async hi -- 36 iteration
#       From worker 10:	Async hi -- 36 iteration
#       From worker 11:	Async hi -- 36 iteration
# 37 ------------------------------------------
#       From worker 2:	Async hi -- 37 iteration
#       From worker 6:	Async hi -- 37 iteration
#       From worker 8:	Async hi -- 37 iteration
#       From worker 11:	Async hi -- 37 iteration
#       From worker 3:	Async hi -- 37 iteration
#       From worker 4:	Async hi -- 37 iteration
#       From worker 5:	Async hi -- 37 iteration
#       From worker 7:	Async hi -- 37 iteration
#       From worker 9:	Async hi -- 37 iteration
#       From worker 10:	Async hi -- 37 iteration
# 38 ------------------------------------------
#       From worker 2:	Async hi -- 38 iteration
#       From worker 6:	Async hi -- 38 iteration
#       From worker 3:	Async hi -- 38 iteration
#       From worker 4:	Async hi -- 38 iteration
#       From worker 5:	Async hi -- 38 iteration
#       From worker 7:	Async hi -- 38 iteration
#       From worker 8:	Async hi -- 38 iteration
#       From worker 9:	Async hi -- 38 iteration
#       From worker 10:	Async hi -- 38 iteration
#       From worker 11:	Async hi -- 38 iteration
# 39 ------------------------------------------
#       From worker 2:	Async hi -- 39 iteration
#       From worker 6:	Async hi -- 39 iteration
#       From worker 9:	Async hi -- 39 iteration
#       From worker 3:	Async hi -- 39 iteration
#       From worker 4:	Async hi -- 39 iteration
#       From worker 5:	Async hi -- 39 iteration
#       From worker 7:	Async hi -- 39 iteration
#       From worker 8:	Async hi -- 39 iteration
#       From worker 10:	Async hi -- 39 iteration
#       From worker 11:	Async hi -- 39 iteration
# 40 ------------------------------------------
#       From worker 2:	Async hi -- 40 iteration
#       From worker 3:	Async hi -- 40 iteration
#       From worker 10:	Async hi -- 40 iteration
#       From worker 4:	Async hi -- 40 iteration
#       From worker 5:	Async hi -- 40 iteration
#       From worker 6:	Async hi -- 40 iteration
#       From worker 7:	Async hi -- 40 iteration
#       From worker 8:	Async hi -- 40 iteration
#       From worker 9:	Async hi -- 40 iteration
#       From worker 11:	Async hi -- 40 iteration
# 41 ------------------------------------------
#       From worker 2:	Async hi -- 41 iteration
#       From worker 3:	Async hi -- 41 iteration
#       From worker 9:	Async hi -- 41 iteration
#       From worker 4:	Async hi -- 41 iteration
#       From worker 5:	Async hi -- 41 iteration
#       From worker 6:	Async hi -- 41 iteration
#       From worker 7:	Async hi -- 41 iteration
#       From worker 8:	Async hi -- 41 iteration
#       From worker 10:	Async hi -- 41 iteration
#       From worker 11:	Async hi -- 41 iteration
# 42 ------------------------------------------
#       From worker 2:	Async hi -- 42 iteration
#       From worker 7:	Async hi -- 42 iteration
#       From worker 10:	Async hi -- 42 iteration
#       From worker 3:	Async hi -- 42 iteration
#       From worker 4:	Async hi -- 42 iteration
#       From worker 5:	Async hi -- 42 iteration
#       From worker 6:	Async hi -- 42 iteration
#       From worker 8:	Async hi -- 42 iteration
#       From worker 9:	Async hi -- 42 iteration
#       From worker 11:	Async hi -- 42 iteration
# 43 ------------------------------------------
#       From worker 2:	Async hi -- 43 iteration
#       From worker 6:	Async hi -- 43 iteration
#       From worker 8:	Async hi -- 43 iteration
#       From worker 3:	Async hi -- 43 iteration
#       From worker 4:	Async hi -- 43 iteration
#       From worker 5:	Async hi -- 43 iteration
#       From worker 7:	Async hi -- 43 iteration
#       From worker 9:	Async hi -- 43 iteration
#       From worker 10:	Async hi -- 43 iteration
#       From worker 11:	Async hi -- 43 iteration
# 44 ------------------------------------------
#       From worker 2:	Async hi -- 44 iteration
#       From worker 6:	Async hi -- 44 iteration
#       From worker 8:	Async hi -- 44 iteration
#       From worker 3:	Async hi -- 44 iteration
#       From worker 4:	Async hi -- 44 iteration
#       From worker 5:	Async hi -- 44 iteration
#       From worker 7:	Async hi -- 44 iteration
#       From worker 9:	Async hi -- 44 iteration
#       From worker 10:	Async hi -- 44 iteration
#       From worker 11:	Async hi -- 44 iteration
# 45 ------------------------------------------
#       From worker 2:	Async hi -- 45 iteration
#       From worker 6:	Async hi -- 45 iteration
#       From worker 9:	Async hi -- 45 iteration
#       From worker 4:	Async hi -- 45 iteration
#       From worker 3:	Async hi -- 45 iteration
#       From worker 5:	Async hi -- 45 iteration
#       From worker 7:	Async hi -- 45 iteration
#       From worker 8:	Async hi -- 45 iteration
#       From worker 10:	Async hi -- 45 iteration
#       From worker 11:	Async hi -- 45 iteration
# 46 ------------------------------------------
#       From worker 2:	Async hi -- 46 iteration
#       From worker 6:	Async hi -- 46 iteration
#       From worker 9:	Async hi -- 46 iteration
#       From worker 10:	Async hi -- 46 iteration
#       From worker 3:	Async hi -- 46 iteration
#       From worker 4:	Async hi -- 46 iteration
#       From worker 5:	Async hi -- 46 iteration
#       From worker 7:	Async hi -- 46 iteration
#       From worker 8:	Async hi -- 46 iteration
#       From worker 11:	Async hi -- 46 iteration
# 47 ------------------------------------------
#       From worker 2:	Async hi -- 47 iteration
#       From worker 6:	Async hi -- 47 iteration
#       From worker 8:	Async hi -- 47 iteration
#       From worker 11:	Async hi -- 47 iteration
#       From worker 3:	Async hi -- 47 iteration
#       From worker 4:	Async hi -- 47 iteration
#       From worker 5:	Async hi -- 47 iteration
#       From worker 7:	Async hi -- 47 iteration
#       From worker 9:	Async hi -- 47 iteration
#       From worker 10:	Async hi -- 47 iteration
# 48 ------------------------------------------
#       From worker 2:	Async hi -- 48 iteration
#       From worker 6:	Async hi -- 48 iteration
#       From worker 9:	Async hi -- 48 iteration
#       From worker 3:	Async hi -- 48 iteration
#       From worker 4:	Async hi -- 48 iteration
#       From worker 5:	Async hi -- 48 iteration
#       From worker 7:	Async hi -- 48 iteration
#       From worker 8:	Async hi -- 48 iteration
#       From worker 10:	Async hi -- 48 iteration
#       From worker 11:	Async hi -- 48 iteration
# 49 ------------------------------------------
#       From worker 2:	Async hi -- 49 iteration
#       From worker 6:	Async hi -- 49 iteration
#       From worker 8:	Async hi -- 49 iteration
#       From worker 10:	Async hi -- 49 iteration
#       From worker 3:	Async hi -- 49 iteration
#       From worker 4:	Async hi -- 49 iteration
#       From worker 5:	Async hi -- 49 iteration
#       From worker 7:	Async hi -- 49 iteration
#       From worker 9:	Async hi -- 49 iteration
#       From worker 11:	Async hi -- 49 iteration
# 50 ------------------------------------------
#       From worker 2:	Async hi -- 50 iteration
#       From worker 6:	Async hi -- 50 iteration
#       From worker 8:	Async hi -- 50 iteration
#       From worker 10:	Async hi -- 50 iteration
#       From worker 3:	Async hi -- 50 iteration
#       From worker 4:	Async hi -- 50 iteration
#       From worker 5:	Async hi -- 50 iteration
#       From worker 7:	Async hi -- 50 iteration
#       From worker 9:	Async hi -- 50 iteration
#       From worker 11:	Async hi -- 50 iteration
# Sync total time: 4.449127399 || Async total time: 0.510679498
# Sync mean time: 0.11408018971794871 || Async mean time: 0.013094346102564103
# Sync std time: 0.0044017415618990904 || Async std time: 0.00028852842577837477
# Sync: [0.109674, 0.109811, 0.109831, 0.109873, 0.109904, 0.109904, 0.109924, 0.109937, 0.109976, 0.109977, 0.110025, 0.110081, 0.110772, 0.110825, 0.11095, 0.110961, 0.110998, 0.111117, 0.112009, 0.112063, 0.112312, 0.112871, 0.11369, 0.113808, 0.113812, 0.115845, 0.117911, 0.117969, 0.118113, 0.119059, 0.119837, 0.119939, 0.120023, 0.120743, 0.120799, 0.120894, 0.12093, 0.120936, 0.121024]
# Async: [0.0126223, 0.0126229, 0.0126716, 0.0127113, 0.0127505, 0.0127604, 0.0127737, 0.0127908, 0.0128146, 0.0128486, 0.012883, 0.0129049, 0.0129243, 0.0129279, 0.0129587, 0.0129777, 0.0129829, 0.0130491, 0.0130515, 0.0130557, 0.0130569, 0.0131089, 0.0131311, 0.0132213, 0.0132267, 0.0132398, 0.0132414, 0.0132708, 0.0133874, 0.0133936, 0.0134134, 0.0134195, 0.0134593, 0.0134639, 0.0134762, 0.0134789, 0.0135189, 0.0135398, 0.0135493]

# %% [markdown]
# **Gráfico**:

# %%
groupedbar(["B_multicast"],
           [syncMeanTime asyncMeanTime],
           yerr = [syncConfTime asyncConfTime],
           label = ["Sync", "Async"],
           ylabel = "Time (seconds)",
           title = "Sync x Async B_multicast",
           framestyle = :box)

# %% [markdown]
# * Qual das duas versões teve o menor tempo de execução? Por quê?
#
# **Resposta**: _A versão assíncrona. Porque na versão assíncrona, cada mensagem é enviada e recebida em paralelo; enquanto a versão síncrona é sequencial: fazendo assim com que a versão assíncrona seja até n vezes mais rápido que a versão síncrona_
#
#
#
# ### Exercício 3: Análise de desempenho do R-multicast (3,0 pontos)
#
# Implemente duas versões do algoritmo R-multicast: uma assíncrona e outra síncrona.
#
# ### Preparations

# %%
@everywhere group global received = Set()

# %% [markdown]
# * R-multicast assíncrono

# %%
@everywhere function R_sync_deliver(group, from, message)
#     global received

    if !(message in received)
        push!(received, message)
        if from != myid()
            B_sync_multicast(group, message)
        end
        println(message)
        sleep(0.01)
    end
end

@everywhere function B_sync_multicast(group, message)
    my_id = myid()
    for i in group
        @sync @spawnat i R_sync_deliver(group, my_id, message)
    end
end

function R_sync_multicast(group, message)
    B_sync_multicast(group, message)
end
# Out:
# R_sync_multicast (generic function with 1 method)

# %% [markdown]
# * R-multicast assíncrono

# %%
@everywhere function R_async_deliver(group, from, message)
#     global received

    if !(message in received)
        push!(received, message)
        if from != myid()
            B_async_multicast(group, message)
        end
        println(message)
        sleep(0.01)
    end
end

@everywhere function B_async_multicast(group, message)
    my_id = myid()
    @sync for i in group
        @spawnat i R_async_deliver(group, my_id, message)
    end
end

function R_async_multicast(group, message)
    B_async_multicast(group, message)
end
# Out:
# R_async_multicast (generic function with 1 method)

# %% [markdown]
# Faça a mesma análise de desempenho para o R-multicast que você fez no Exercício 2.

# %%
syncTimes = []
for i in 1:iterations
    println("$i ------------------------------------------")
    push!(syncTimes, @elapsed R_sync_multicast(group, "Sync  hi -- $i iteration"))
end

asyncTimes = []
for i in 1:iterations
    println("$i ------------------------------------------")
    push!(asyncTimes, @elapsed R_async_multicast(group, "Async hi -- $i iteration"))
end

syncTimes, asyncTimes = Array{Float64}(syncTimes), Array{Float64}(asyncTimes)
sort!(syncTimes), sort!(asyncTimes)
deleteat!(syncTimes, UnitRange(length(syncTimes) - 10, length(syncTimes)))
deleteat!(asyncTimes, UnitRange(length(asyncTimes) - 10, length(asyncTimes)))
syncTotalTime, asyncTotalTime = sum(syncTimes), sum(asyncTimes)
syncMeanTime, asyncMeanTime = mean(syncTimes), mean(asyncTimes)
syncStdTime, asyncStdTime = std(syncTimes), std(asyncTimes)
syncConfTime, asyncConfTime = z*syncStdTime/sqrt(length(syncTimes)), z*asyncStdTime/sqrt(length(asyncTimes))

println("Sync total time: $syncTotalTime || Async total time: $asyncTotalTime")
println("Sync mean time: $syncMeanTime || Async mean time: $asyncMeanTime")
println("Sync std time: $syncStdTime || Async std time: $asyncStdTime")
println("Sync: $syncTimes")
println("Async: $asyncTimes")
# Out:
# 1 ------------------------------------------
#       From worker 14:	Sync  hi -- 1 iteration
#       From worker 13:	Sync  hi -- 1 iteration
#       From worker 12:	Sync  hi -- 1 iteration
# 2 ------------------------------------------
#       From worker 14:	Sync  hi -- 2 iteration
#       From worker 13:	Sync  hi -- 2 iteration
#       From worker 12:	Sync  hi -- 2 iteration
# 3 ------------------------------------------
#       From worker 14:	Sync  hi -- 3 iteration
#       From worker 13:	Sync  hi -- 3 iteration
#       From worker 12:	Sync  hi -- 3 iteration
# 4 ------------------------------------------
#       From worker 14:	Sync  hi -- 4 iteration
#       From worker 13:	Sync  hi -- 4 iteration
#       From worker 12:	Sync  hi -- 4 iteration
# 5 ------------------------------------------
#       From worker 14:	Sync  hi -- 5 iteration
#       From worker 13:	Sync  hi -- 5 iteration
#       From worker 12:	Sync  hi -- 5 iteration
# 6 ------------------------------------------
#       From worker 14:	Sync  hi -- 6 iteration
#       From worker 13:	Sync  hi -- 6 iteration
#       From worker 12:	Sync  hi -- 6 iteration
# 7 ------------------------------------------
#       From worker 14:	Sync  hi -- 7 iteration
#       From worker 13:	Sync  hi -- 7 iteration
#       From worker 12:	Sync  hi -- 7 iteration
# 8 ------------------------------------------
#       From worker 14:	Sync  hi -- 8 iteration
#       From worker 13:	Sync  hi -- 8 iteration
#       From worker 12:	Sync  hi -- 8 iteration
# 9 ------------------------------------------
#       From worker 14:	Sync  hi -- 9 iteration
#       From worker 13:	Sync  hi -- 9 iteration
#       From worker 12:	Sync  hi -- 9 iteration
# 10 ------------------------------------------
#       From worker 14:	Sync  hi -- 10 iteration
#       From worker 13:	Sync  hi -- 10 iteration
#       From worker 12:	Sync  hi -- 10 iteration
# 11 ------------------------------------------
#       From worker 14:	Sync  hi -- 11 iteration
#       From worker 13:	Sync  hi -- 11 iteration
#       From worker 12:	Sync  hi -- 11 iteration
# 12 ------------------------------------------
#       From worker 14:	Sync  hi -- 12 iteration
#       From worker 13:	Sync  hi -- 12 iteration
#       From worker 12:	Sync  hi -- 12 iteration
# 13 ------------------------------------------
#       From worker 14:	Sync  hi -- 13 iteration
#       From worker 13:	Sync  hi -- 13 iteration
#       From worker 12:	Sync  hi -- 13 iteration
# 14 ------------------------------------------
#       From worker 14:	Sync  hi -- 14 iteration
#       From worker 13:	Sync  hi -- 14 iteration
#       From worker 12:	Sync  hi -- 14 iteration
# 15 ------------------------------------------
#       From worker 14:	Sync  hi -- 15 iteration
#       From worker 13:	Sync  hi -- 15 iteration
#       From worker 12:	Sync  hi -- 15 iteration
# 16 ------------------------------------------
#       From worker 14:	Sync  hi -- 16 iteration
#       From worker 13:	Sync  hi -- 16 iteration
#       From worker 12:	Sync  hi -- 16 iteration
# 17 ------------------------------------------
#       From worker 14:	Sync  hi -- 17 iteration
#       From worker 13:	Sync  hi -- 17 iteration
#       From worker 12:	Sync  hi -- 17 iteration
# 18 ------------------------------------------
#       From worker 14:	Sync  hi -- 18 iteration
#       From worker 13:	Sync  hi -- 18 iteration
#       From worker 12:	Sync  hi -- 18 iteration
# 19 ------------------------------------------
#       From worker 14:	Sync  hi -- 19 iteration
#       From worker 13:	Sync  hi -- 19 iteration
#       From worker 12:	Sync  hi -- 19 iteration
# 20 ------------------------------------------
#       From worker 14:	Sync  hi -- 20 iteration
#       From worker 13:	Sync  hi -- 20 iteration
#       From worker 12:	Sync  hi -- 20 iteration
# 21 ------------------------------------------
#       From worker 14:	Sync  hi -- 21 iteration
#       From worker 13:	Sync  hi -- 21 iteration
#       From worker 12:	Sync  hi -- 21 iteration
# 22 ------------------------------------------
#       From worker 14:	Sync  hi -- 22 iteration
#       From worker 13:	Sync  hi -- 22 iteration
#       From worker 12:	Sync  hi -- 22 iteration
# 23 ------------------------------------------
#       From worker 14:	Sync  hi -- 23 iteration
#       From worker 13:	Sync  hi -- 23 iteration
#       From worker 12:	Sync  hi -- 23 iteration
# 24 ------------------------------------------
#       From worker 14:	Sync  hi -- 24 iteration
#       From worker 13:	Sync  hi -- 24 iteration
#       From worker 12:	Sync  hi -- 24 iteration
# 25 ------------------------------------------
#       From worker 14:	Sync  hi -- 25 iteration
#       From worker 13:	Sync  hi -- 25 iteration
#       From worker 12:	Sync  hi -- 25 iteration
# 26 ------------------------------------------
#       From worker 14:	Sync  hi -- 26 iteration
#       From worker 13:	Sync  hi -- 26 iteration
#       From worker 12:	Sync  hi -- 26 iteration
# 27 ------------------------------------------
#       From worker 14:	Sync  hi -- 27 iteration
#       From worker 13:	Sync  hi -- 27 iteration
#       From worker 12:	Sync  hi -- 27 iteration
# 28 ------------------------------------------
#       From worker 14:	Sync  hi -- 28 iteration
#       From worker 13:	Sync  hi -- 28 iteration
#       From worker 12:	Sync  hi -- 28 iteration
# 29 ------------------------------------------
#       From worker 14:	Sync  hi -- 29 iteration
#       From worker 13:	Sync  hi -- 29 iteration
#       From worker 12:	Sync  hi -- 29 iteration
# 30 ------------------------------------------
#       From worker 14:	Sync  hi -- 30 iteration
#       From worker 13:	Sync  hi -- 30 iteration
#       From worker 12:	Sync  hi -- 30 iteration
# 31 ------------------------------------------
#       From worker 14:	Sync  hi -- 31 iteration
#       From worker 13:	Sync  hi -- 31 iteration
#       From worker 12:	Sync  hi -- 31 iteration
# 32 ------------------------------------------
#       From worker 14:	Sync  hi -- 32 iteration
#       From worker 13:	Sync  hi -- 32 iteration
#       From worker 12:	Sync  hi -- 32 iteration
# 33 ------------------------------------------
#       From worker 14:	Sync  hi -- 33 iteration
#       From worker 13:	Sync  hi -- 33 iteration
#       From worker 12:	Sync  hi -- 33 iteration
# 34 ------------------------------------------
#       From worker 14:	Sync  hi -- 34 iteration
#       From worker 13:	Sync  hi -- 34 iteration
#       From worker 12:	Sync  hi -- 34 iteration
# 35 ------------------------------------------
#       From worker 14:	Sync  hi -- 35 iteration
#       From worker 13:	Sync  hi -- 35 iteration
#       From worker 12:	Sync  hi -- 35 iteration
# 36 ------------------------------------------
#       From worker 14:	Sync  hi -- 36 iteration
#       From worker 13:	Sync  hi -- 36 iteration
#       From worker 12:	Sync  hi -- 36 iteration
# 37 ------------------------------------------
#       From worker 14:	Sync  hi -- 37 iteration
#       From worker 13:	Sync  hi -- 37 iteration
#       From worker 12:	Sync  hi -- 37 iteration
# 38 ------------------------------------------
#       From worker 14:	Sync  hi -- 38 iteration
#       From worker 13:	Sync  hi -- 38 iteration
#       From worker 12:	Sync  hi -- 38 iteration
# 39 ------------------------------------------
#       From worker 14:	Sync  hi -- 39 iteration
#       From worker 13:	Sync  hi -- 39 iteration
#       From worker 12:	Sync  hi -- 39 iteration
# 40 ------------------------------------------
#       From worker 14:	Sync  hi -- 40 iteration
#       From worker 13:	Sync  hi -- 40 iteration
#       From worker 12:	Sync  hi -- 40 iteration
# 41 ------------------------------------------
#       From worker 14:	Sync  hi -- 41 iteration
#       From worker 13:	Sync  hi -- 41 iteration
#       From worker 12:	Sync  hi -- 41 iteration
# 42 ------------------------------------------
#       From worker 14:	Sync  hi -- 42 iteration
#       From worker 13:	Sync  hi -- 42 iteration
#       From worker 12:	Sync  hi -- 42 iteration
# 43 ------------------------------------------
#       From worker 14:	Sync  hi -- 43 iteration
#       From worker 13:	Sync  hi -- 43 iteration
#       From worker 12:	Sync  hi -- 43 iteration
# 44 ------------------------------------------
#       From worker 14:	Sync  hi -- 44 iteration
#       From worker 13:	Sync  hi -- 44 iteration
#       From worker 12:	Sync  hi -- 44 iteration
# 45 ------------------------------------------
#       From worker 14:	Sync  hi -- 45 iteration
#       From worker 13:	Sync  hi -- 45 iteration
#       From worker 12:	Sync  hi -- 45 iteration
# 46 ------------------------------------------
#       From worker 14:	Sync  hi -- 46 iteration
#       From worker 13:	Sync  hi -- 46 iteration
#       From worker 12:	Sync  hi -- 46 iteration
# 47 ------------------------------------------
#       From worker 14:	Sync  hi -- 47 iteration
#       From worker 13:	Sync  hi -- 47 iteration
#       From worker 12:	Sync  hi -- 47 iteration
# 48 ------------------------------------------
#       From worker 14:	Sync  hi -- 48 iteration
#       From worker 13:	Sync  hi -- 48 iteration
#       From worker 12:	Sync  hi -- 48 iteration
# 49 ------------------------------------------
#       From worker 14:	Sync  hi -- 49 iteration
#       From worker 13:	Sync  hi -- 49 iteration
#       From worker 12:	Sync  hi -- 49 iteration
# 50 ------------------------------------------
#       From worker 14:	Sync  hi -- 50 iteration
#       From worker 13:	Sync  hi -- 50 iteration
#       From worker 12:	Sync  hi -- 50 iteration
# 1 ------------------------------------------
#       From worker 13:	Async hi -- 1 iteration
#       From worker 12:	Async hi -- 1 iteration
#       From worker 14:	Async hi -- 1 iteration
# 2 ------------------------------------------
#       From worker 14:	Async hi -- 2 iteration
#       From worker 12:	Async hi -- 2 iteration
#       From worker 13:	Async hi -- 2 iteration
# 3 ------------------------------------------
#       From worker 13:	Async hi -- 3 iteration
#       From worker 14:	Async hi -- 3 iteration
#       From worker 12:	Async hi -- 3 iteration
# 4 ------------------------------------------
#       From worker 13:	Async hi -- 4 iteration
#       From worker 14:	Async hi -- 4 iteration
#       From worker 12:	Async hi -- 4 iteration
# 5 ------------------------------------------
#       From worker 12:	Async hi -- 5 iteration
#       From worker 14:	Async hi -- 5 iteration
#       From worker 13:	Async hi -- 5 iteration
# 6 ------------------------------------------
#       From worker 14:	Async hi -- 6 iteration
#       From worker 12:	Async hi -- 6 iteration
#       From worker 13:	Async hi -- 6 iteration
# 7 ------------------------------------------
#       From worker 14:	Async hi -- 7 iteration
#       From worker 13:	Async hi -- 7 iteration
#       From worker 12:	Async hi -- 7 iteration
# 8 ------------------------------------------
#       From worker 13:	Async hi -- 8 iteration
#       From worker 14:	Async hi -- 8 iteration
#       From worker 12:	Async hi -- 8 iteration
# 9 ------------------------------------------
#       From worker 14:	Async hi -- 9 iteration
#       From worker 12:	Async hi -- 9 iteration
#       From worker 13:	Async hi -- 9 iteration
# 10 ------------------------------------------
#       From worker 13:	Async hi -- 10 iteration
#       From worker 12:	Async hi -- 10 iteration
#       From worker 14:	Async hi -- 10 iteration
# 11 ------------------------------------------
#       From worker 12:	Async hi -- 11 iteration
#       From worker 13:	Async hi -- 11 iteration
#       From worker 14:	Async hi -- 11 iteration
# 12 ------------------------------------------
#       From worker 14:	Async hi -- 12 iteration
#       From worker 13:	Async hi -- 12 iteration
#       From worker 12:	Async hi -- 12 iteration
# 13 ------------------------------------------
#       From worker 13:	Async hi -- 13 iteration
#       From worker 12:	Async hi -- 13 iteration
#       From worker 14:	Async hi -- 13 iteration
# 14 ------------------------------------------
#       From worker 13:	Async hi -- 14 iteration
#       From worker 12:	Async hi -- 14 iteration
#       From worker 14:	Async hi -- 14 iteration
# 15 ------------------------------------------
#       From worker 14:	Async hi -- 15 iteration
#       From worker 12:	Async hi -- 15 iteration
#       From worker 13:	Async hi -- 15 iteration
# 16 ------------------------------------------
#       From worker 12:	Async hi -- 16 iteration
#       From worker 13:	Async hi -- 16 iteration
#       From worker 14:	Async hi -- 16 iteration
# 17 ------------------------------------------
#       From worker 12:	Async hi -- 17 iteration
#       From worker 13:	Async hi -- 17 iteration
#       From worker 14:	Async hi -- 17 iteration
# 18 ------------------------------------------
#       From worker 12:	Async hi -- 18 iteration
#       From worker 14:	Async hi -- 18 iteration
#       From worker 13:	Async hi -- 18 iteration
# 19 ------------------------------------------
#       From worker 13:	Async hi -- 19 iteration
#       From worker 14:	Async hi -- 19 iteration
#       From worker 12:	Async hi -- 19 iteration
# 20 ------------------------------------------
#       From worker 12:	Async hi -- 20 iteration
#       From worker 14:	Async hi -- 20 iteration
#       From worker 13:	Async hi -- 20 iteration
# 21 ------------------------------------------
#       From worker 14:	Async hi -- 21 iteration
#       From worker 12:	Async hi -- 21 iteration
#       From worker 13:	Async hi -- 21 iteration
# 22 ------------------------------------------
#       From worker 12:	Async hi -- 22 iteration
#       From worker 13:	Async hi -- 22 iteration
#       From worker 14:	Async hi -- 22 iteration
# 23 ------------------------------------------
#       From worker 12:	Async hi -- 23 iteration
#       From worker 13:	Async hi -- 23 iteration
#       From worker 14:	Async hi -- 23 iteration
# 24 ------------------------------------------
#       From worker 12:	Async hi -- 24 iteration
#       From worker 13:	Async hi -- 24 iteration
#       From worker 14:	Async hi -- 24 iteration
# 25 ------------------------------------------
#       From worker 13:	Async hi -- 25 iteration
#       From worker 14:	Async hi -- 25 iteration
#       From worker 12:	Async hi -- 25 iteration
# 26 ------------------------------------------
#       From worker 14:	Async hi -- 26 iteration
#       From worker 12:	Async hi -- 26 iteration
#       From worker 13:	Async hi -- 26 iteration
# 27 ------------------------------------------
#       From worker 12:	Async hi -- 27 iteration
#       From worker 14:	Async hi -- 27 iteration
#       From worker 13:	Async hi -- 27 iteration
# 28 ------------------------------------------
#       From worker 13:	Async hi -- 28 iteration
#       From worker 12:	Async hi -- 28 iteration
#       From worker 14:	Async hi -- 28 iteration
# 29 ------------------------------------------
#       From worker 13:	Async hi -- 29 iteration
#       From worker 14:	Async hi -- 29 iteration
#       From worker 12:	Async hi -- 29 iteration
# 30 ------------------------------------------
#       From worker 14:	Async hi -- 30 iteration
#       From worker 13:	Async hi -- 30 iteration
#       From worker 12:	Async hi -- 30 iteration
# 31 ------------------------------------------
#       From worker 12:	Async hi -- 31 iteration
#       From worker 13:	Async hi -- 31 iteration
#       From worker 14:	Async hi -- 31 iteration
# 32 ------------------------------------------
#       From worker 12:	Async hi -- 32 iteration
#       From worker 14:	Async hi -- 32 iteration
#       From worker 13:	Async hi -- 32 iteration
# 33 ------------------------------------------
#       From worker 12:	Async hi -- 33 iteration
#       From worker 13:	Async hi -- 33 iteration
#       From worker 14:	Async hi -- 33 iteration
# 34 ------------------------------------------
#       From worker 14:	Async hi -- 34 iteration
#       From worker 12:	Async hi -- 34 iteration
#       From worker 13:	Async hi -- 34 iteration
# 35 ------------------------------------------
#       From worker 13:	Async hi -- 35 iteration
#       From worker 12:	Async hi -- 35 iteration
#       From worker 14:	Async hi -- 35 iteration
# 36 ------------------------------------------
#       From worker 13:	Async hi -- 36 iteration
#       From worker 12:	Async hi -- 36 iteration
#       From worker 14:	Async hi -- 36 iteration
# 37 ------------------------------------------
#       From worker 13:	Async hi -- 37 iteration
#       From worker 12:	Async hi -- 37 iteration
#       From worker 14:	Async hi -- 37 iteration
# 38 ------------------------------------------
#       From worker 14:	Async hi -- 38 iteration
#       From worker 12:	Async hi -- 38 iteration
#       From worker 13:	Async hi -- 38 iteration
# 39 ------------------------------------------
#       From worker 12:	Async hi -- 39 iteration
#       From worker 14:	Async hi -- 39 iteration
#       From worker 13:	Async hi -- 39 iteration
# 40 ------------------------------------------
#       From worker 12:	Async hi -- 40 iteration
#       From worker 13:	Async hi -- 40 iteration
#       From worker 14:	Async hi -- 40 iteration
# 41 ------------------------------------------
#       From worker 13:	Async hi -- 41 iteration
#       From worker 12:	Async hi -- 41 iteration
#       From worker 14:	Async hi -- 41 iteration
# 42 ------------------------------------------
#       From worker 12:	Async hi -- 42 iteration
#       From worker 13:	Async hi -- 42 iteration
#       From worker 14:	Async hi -- 42 iteration
# 43 ------------------------------------------
#       From worker 13:	Async hi -- 43 iteration
#       From worker 12:	Async hi -- 43 iteration
#       From worker 14:	Async hi -- 43 iteration
# 44 ------------------------------------------
#       From worker 13:	Async hi -- 44 iteration
#       From worker 12:	Async hi -- 44 iteration
#       From worker 14:	Async hi -- 44 iteration
# 45 ------------------------------------------
#       From worker 12:	Async hi -- 45 iteration
#       From worker 13:	Async hi -- 45 iteration
#       From worker 14:	Async hi -- 45 iteration
# 46 ------------------------------------------
#       From worker 12:	Async hi -- 46 iteration
#       From worker 13:	Async hi -- 46 iteration
#       From worker 14:	Async hi -- 46 iteration
# 47 ------------------------------------------
#       From worker 12:	Async hi -- 47 iteration
#       From worker 13:	Async hi -- 47 iteration
#       From worker 14:	Async hi -- 47 iteration
# 48 ------------------------------------------
#       From worker 14:	Async hi -- 48 iteration
#       From worker 12:	Async hi -- 48 iteration
#       From worker 13:	Async hi -- 48 iteration
# 49 ------------------------------------------
#       From worker 12:	Async hi -- 49 iteration
#       From worker 14:	Async hi -- 49 iteration
#       From worker 13:	Async hi -- 49 iteration
# 50 ------------------------------------------
#       From worker 13:	Async hi -- 50 iteration
#       From worker 12:	Async hi -- 50 iteration
#       From worker 14:	Async hi -- 50 iteration
# Sync total time: 1.3595619049999998 || Async total time: 0.476461598
# Sync mean time: 0.034860561666666665 || Async mean time: 0.01221696405128205
# Sync std time: 0.0008077761277422275 || Async std time: 0.00033021755682770786
# Sync: [0.0337392, 0.0337641, 0.0338701, 0.0339251, 0.0339611, 0.0340516, 0.0340548, 0.0340674, 0.0340981, 0.0341415, 0.0342641, 0.0345712, 0.0346361, 0.0346396, 0.0346498, 0.034675, 0.034733, 0.0347444, 0.034783, 0.0348213, 0.0348454, 0.0348982, 0.0348996, 0.0349198, 0.0349273, 0.0349484, 0.0349668, 0.034976, 0.0349776, 0.035007, 0.0351136, 0.0352004, 0.0354396, 0.0354744, 0.0361057, 0.0361304, 0.0367664, 0.0368501, 0.0369247]
# Async: [0.0117622, 0.0117955, 0.0117974, 0.0118253, 0.0118563, 0.0118611, 0.0118832, 0.0119008, 0.0119036, 0.0119097, 0.0119292, 0.0119407, 0.0119452, 0.0119498, 0.0119652, 0.0120508, 0.0121078, 0.0121166, 0.0121291, 0.0121504, 0.0121785, 0.0121921, 0.0122335, 0.0122393, 0.0123788, 0.0124277, 0.0124425, 0.0124687, 0.0124818, 0.012497, 0.0125884, 0.0125907, 0.012615, 0.0126206, 0.0127005, 0.0127112, 0.0127449, 0.0127566, 0.0128139]

# %% [markdown]
# **Gráfico**: _por aqui_

# %%
groupedbar(["R_multicast"],
           [syncMeanTime asyncMeanTime],
           yerr = [syncConfTime asyncConfTime],
           label = ["Sync", "Async"],
           ylabel = "Time (seconds)",
           title = "Sync x Async R_multicast",
           framestyle = :box)

# %% [markdown]
# * Qual das duas versões (R-multicast síncrono e assíncrono) teve o menor tempo de execução? Por quê?
#
# **Resposta**: _Novamente, a versão assíncrona tem vantagem de tempo sobre a síncrona. E o motivo é o mesmo, a única diferença é que agora existe mais trabalho a ser feito, visto que para garantir a confiabilidade: o R_multicast precisa mandar mais mensagens; aumentando assim a diferença entre os dois, como pode ser observada no gráfico acima._
#
#
#
# ### Exercício 4: Análise de desempenho: B-multicast vs. R-multicast (3,0 pontos)
#
# Para cada uma das comparações abaixo, qual dos algoritmos teve o menor tempo de execução? Por quê?
#
# * B-multicast assíncrono vs. R-multicast assíncrono.
#
#
# **Resposta**: _em itálico_
#
# * B-multicast síncrono vs. R-multicast síncrono.
#
#
# **Resposta**: _em itálico_
#
# ## Entrega
#
# As respostas deverão ser entregues nos devidos campos desse arquivo, ou seja, em [Markdown](https://en.wikipedia.org/wiki/Markdown) e no formato [IJulia Notebook](https://github.com/JuliaLang/IJulia.jl).
#
# O programa deve ser implementado na linguagem de programação **Julia**. Seu trabalho será testado na [JuliaBox](https://juliabox.com), portanto teste seu arquivo IJulia na JulizBox antes de enviá-lo.
#
#
# ### Forma
#
# O arquivo IJulia Notebook deverá ser entregue ao Professor **exclusivamente através do Google Classroom**.
#
#
#
# A responsabilidade sobre a integridade do arquivo contendo trabalho é exclusivamente dos discentes. Serão ignorados os trabalhos cujos arquivos não conseguirem ser abertos pelo Professor.
#
# ### Prazos
#
# O prazo de entrega sem atraso é o dia **18/11/17**.
#
# Trabalhos entregues com atraso serão aceitos, no máximo, até o o dia **19/11/17**. Serão descontados 5% da nota obtida por dia de atraso.
#
#
# ## Pontuação extra
#
# O(a) discente que realizar mais tarefas, além do que foi especificado neste trabalho, o professor atribuirá de 0,5 a 1,0 ponto extra a depender da relevância da contribuição no programa. O critério será decidido pelo professor.
#
# O(a) discente deve indicar qual é a tarefa executada. Por exemplo, adição de funcionalidades, armazenamento de dados em arquivo, documentação de código, comentários em inglês sem erros ortográficos, etc.
#
#
# **Plágio** A nota zero será atribuída caso haja qualquer tipo de cópia parcial ou integral assim como as devidas medidas legais. Leia a [cartilha sobre plágio](http://www.noticias.uff.br/arquivos/cartilha-sobre-plagio-academico.pdf).
#
# ## Disclaimer
#
# Esse material foi elaborado pelo [Prof. André Lage Freitas](https://sites.google.com/a/ic.ufal.br/andrelage/) e está licenciado sob a licença _GNU General Public License v3.0_.
